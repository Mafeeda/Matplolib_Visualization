# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mtcars = pd.read_csv('mtcars.csv')
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.shape
# Out:
# (32, 12)

# %%
mtcars.columns
# Out:
# Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
mtcars.axes
# Out:
# [RangeIndex(start=0, stop=32, step=1),
#  Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#         'gear', 'carb'],
#        dtype='object')]

# %% [markdown]
# ## Table

# %%
pd.crosstab(mtcars.gear,mtcars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
pd.crosstab(mtcars.mpg,mtcars.cyl).head(10)
# Out:
# cyl   4  6  8
# mpg
# 10.4  0  0  2
# 13.3  0  0  1
# 14.3  0  0  1
# 14.7  0  0  1
# 15.0  0  0  1
# 15.2  0  0  2
# 15.5  0  0  1
# 15.8  0  0  1
# 16.4  0  0  1
# 17.3  0  0  1

# %% [markdown]
# ## Bar plot between 2 different categories

# %%
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='gear'>

# %%
pd.crosstab(mtcars.mpg,mtcars.cyl).plot()
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
pd.crosstab(mtcars.mpg,mtcars.cyl).plot(kind ='box')
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(mtcars.mpg,mtcars.cyl).head(10).plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## Plotting single category

# %%
mtcars["gear"].value_counts()
mtcars.gear.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='gear'>

# %%
ax = plt.subplots(figsize = (10,5))
mtcars.mpg.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='mpg'>

# %%
mtcars.mpg.head(10).value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='mpg'>

# %%
mtcars.mpg.head(10).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
mtcars.name.value_counts()
# Out:
# Merc 280C              1
# Merc 450SLC            1
# Pontiac Firebird       1
# Camaro Z28             1
# Honda Civic            1
# Valiant                1
# Fiat X1-9              1
# Hornet Sportabout      1
# Ford Pantera L         1
# Mazda RX4 Wag          1
# Merc 450SL             1
# Merc 240D              1
# Hornet 4 Drive         1
# Maserati Bora          1
# Merc 230               1
# Fiat 128               1
# Toyota Corolla         1
# Merc 450SE             1
# Datsun 710             1
# Chrysler Imperial      1
# Lincoln Continental    1
# Merc 280               1
# Lotus Europa           1
# Mazda RX4              1
# Porsche 914-2          1
# Cadillac Fleetwood     1
# Duster 360             1
# Toyota Corona          1
# AMC Javelin            1
# Volvo 142E             1
# Ferrari Dino           1
# Dodge Challenger       1
# Name: name, dtype: int64

# %%
mtcars.name.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='name'>

# %%
mtcars.name.head(10).value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='name'>

# %% [markdown]
# ## Scatter plot for two variables

# %%
plt.scatter(mtcars.mpg,mtcars.qsec)

# %%
plt.scatter(x = 'name', y = 'mpg', data = mtcars)

# %%
plt.scatter(x = 'name', y = 'mpg', data = mtcars.head(10))

# %%
plt.scatter(mtcars.name,mtcars.mpg)

# %% [markdown]
# ## Histogram

# %%
plt.hist(mtcars['mpg'])
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars.cyl)
# Out:
# (array([11.,  0.,  0.,  0.,  0.,  7.,  0.,  0.,  0., 14.]),
#  array([4. , 4.4, 4.8, 5.2, 5.6, 6. , 6.4, 6.8, 7.2, 7.6, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars['mpg'],facecolor ="peru",edgecolor ="blue",bins =5)
#creates histogram with 5bins and colours filled init.
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(mtcars['disp'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f90c5cb7070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f90c5cb7730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f90c5c5fcd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f90c5cb7df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f90c5cd5190>],
#  'means': []}

# %%
plt.boxplot(mtcars['mpg'],vert =False);
plt.ylabel("MPG");
plt.xlabel("Boxplot");
plt.title("Boxplot")  # for vertical
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
# Box plot using Seaborn
import seaborn as sns

# %%
sns.boxplot(mtcars.mpg.head(10),mtcars.qsec.head(10))
# Out:
# /Users/a/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg', ylabel='qsec'>

# %% [markdown]
# ## Violin Plot

# %%
plt.violinplot(mtcars["mpg"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f90c7553f40>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f90c7bec6d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f90c75703a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f90c75706a0>}
